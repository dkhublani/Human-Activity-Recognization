# %%
install.packages('class')
install.packages('readr')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(class)
library(readr)
X_train <- read_delim("/home/dupad/Desktop/613/project/appendix/X_train.txt","\t", escape_double = FALSE, trim_ws = TRUE)
head(X_train)
# Out:
# Warning message:
# ...

# %%
y_train <- read_csv("/home/dupad/Desktop/613/project/appendix/y_train.txt")
y_train$Y1<-as.factor(y_train$Y1)
head(y_train)
# Out:
# Parsed with column specification:
# cols(
#   Y1 = col_integer()
# )
#   Y1
# 1 5
# 2 5
# 3 5
# 4 5
# 5 5
# 6 5

# %%
X_test <- read_delim("/home/dupad/Desktop/613/project/appendix/X_test.txt", "\t", escape_double = FALSE, trim_ws = TRUE)
head(X_test)
# Out:
# Warning message:
# ...

# %%
y_test <- read_csv("/home/dupad/Desktop/613/project/appendix/y_test.txt")
# Out:
# Parsed with column specification:
# cols(
#   Y1 = col_integer()
# )

# %%
head(y_test)
# Out:
#   Y1
# 1 5
# 2 5
# 3 5
# 4 5
# 5 5
# 6 5

# %%
y_test$Y<-as.factor(y_test$Y1)

# %%
Train<-data.frame(y_train,X_train)

# %%
#Loading traing and testing data sets obtained after dimension reduction using PCA
PCA_train_10 <- read_csv("/home/dupad/Desktop/613/project/appendix/PCA.10.csv")
PCA_train_10<-PCA_train_10[,3:12]
PCA_train_10<-data.frame(y_train,PCA_train_10)

PCA_train_40 <- read_csv("/home/dupad/Desktop/613/project/appendix/PCA.40.csv")
PCA_train_40<-PCA_train_40[,3:42]
PCA_train_40<-data.frame(y_train,PCA_train_40)


PCA_train_63 <- read_csv("/home/dupad/Desktop/613/project/appendix/PCA.63.csv")
PCA_train_63<-PCA_train_63[,3:65]
PCA_train_63<-data.frame(y_train,PCA_train_63)

PCA_test_10 <- read_csv("/home/dupad/Desktop/613/project/appendix/PCA_test.10.csv")
PCA_test_10<-PCA_test_10[,3:12]

PCA_test_40 <- read_csv("/home/dupad/Desktop/613/project/appendix/PCA_test.40.csv")
PCA_test_40<-PCA_test_40[,3:42]

PCA_test_63 <- read_csv("/home/dupad/Desktop/613/project/appendix/PCA_test.63.csv")
PCA_test_63<-PCA_test_63[,3:65]
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_integer(),
#   Y1 = col_integer(),
#   PC1 = col_double(),
#   PC2 = col_double(),
#   PC3 = col_double(),
#   PC4 = col_double(),
#   PC5 = col_double(),
#   PC6 = col_double(),
#   PC7 = col_double(),
#   PC8 = col_double(),
#   PC9 = col_double(),
#   PC10 = col_double()
# )
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   .default = col_double(),
#   X1 = col_integer(),
#   Activity = col_integer()
# )
# See spec(...) for full column specifications.
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   .default = col_double(),
#   X1 = col_integer(),
#   Y1 = col_integer()
# )
# See spec(...) for full column specifications.
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_integer(),
# ...

# %%
install.packages('caret')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#Applying knn method to find best k for repective models using Cross-Validation error

library(caret)
ctrl <- trainControl(method="cv",number = 10 )  
knn.PCA.10<-train(Y1~.,data=PCA_train_10,trControl=ctrl,method="knn")
print(knn.PCA.10)
temp<-predict(knn.PCA.10,newdata = PCA_test_10)
table(temp,y_test$Y)
error_rate.knn.PCA.10<-mean(temp != y_test$Y)
error_rate.knn.PCA.10
# Out:
# k-Nearest Neighbors
#
# 7352 samples
#   10 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 6617, 6615, 6617, 6617, 6619, 6617, ...
# Resampling results across tuning parameters:
#
#   k  Accuracy   Kappa
#   5  0.8838437  0.8601235
#   7  0.8811217  0.8568365
#   9  0.8856136  0.8622307
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was k = 9.
#
# temp   1   2   3   4   5   6
#    1 476  53  63   0   0   0
#    2   5 401  75   1   0   0
#    3  15  17 282   0   0   0
#    4   0   0   0 276  59  42
#    5   0   0   0 211 473   1
#    6   0   0   0   3   0 494
# [1] 0.1849338

# %%
knn.PCA.40<-train(Y1~.,data=PCA_train_40,trControl=ctrl,method="knn")
print(knn.PCA.40)
temp<-predict(knn.PCA.40,newdata = PCA_test_40)
table(temp,y_test$Y)
error_rate.knn.PCA.40<-mean(temp != y_test$Y)
error_rate.knn.PCA.40

knn.PCA.63<-train(Y1~.,data=PCA_train_63,trControl=ctrl,method="knn")
print(knn.PCA.63)
temp<-predict(knn.PCA.63,newdata = PCA_test_63)
table(temp,y_test$Y)
error_rate.knn.PCA.63<-mean(temp != y_test$Y)
error_rate.knn.PCA.63
# Out:
# k-Nearest Neighbors
#
# 7352 samples
#   40 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 6617, 6619, 6615, 6618, 6616, 6615, ...
# Resampling results across tuning parameters:
#
#   k  Accuracy   Kappa
#   5  0.9387940  0.9263021
#   7  0.9397503  0.9274462
#   9  0.9377078  0.9249843
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was k = 7.
#
# temp   1   2   3   4   5   6
#    1 469  44  57   0   0   0
#    2  12 424  52   1   0   0
#    3  15   3 311   0   0   0
#    4   0   0   0 354  67  23
#    5   0   0   0 134 465  10
#    6   0   0   0   2   0 504
# [1] 0.1425178
# k-Nearest Neighbors
#
# 7352 samples
#   63 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 6617, 6616, 6616, 6616, 6618, 6617, ...
# ...

# %%
#Lodaing training and testing data set obtained after best subset selection of variables using Random Forest
install.packages('MASS')
library(MASS)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
subset_train <- read_csv("/home/dupad/Desktop/613/project/appendix/subset_train.csv")
subset_train<-subset_train[,2:38]
subset_train$Y1<-factor(subset_train$Y1)
subset_test<- read_csv("/home/dupad/Desktop/613/project/appendix/subset_test.csv")
subset_test<-subset_test[,3:38]
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   .default = col_double(),
#   X1 = col_integer(),
#   Y1 = col_integer()
# )
# See spec(...) for full column specifications.
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   .default = col_double(),
#   X1 = col_integer(),
#   Y1 = col_integer()
# )
# See spec(...) for full column specifications.

# %%
#Using knn Models and getting Cross Validated error to fid best k and best model
knn.subset<-train(Y1~.,data=subset_train,trControl=ctrl,method="knn")
print(knn.subset)
temp<-predict(knn.subset,newdata = subset_test)
table(temp,y_test$Y)
error_rate.knn.subset<-mean(temp != y_test$Y)
error_rate.knn.subset
# Out:
# k-Nearest Neighbors
#
# 7352 samples
#   36 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 6616, 6617, 6616, 6616, 6616, 6618, ...
# Resampling results across tuning parameters:
#
#   k  Accuracy   Kappa
#   5  0.9427329  0.9310559
#   7  0.9405588  0.9284377
#   9  0.9415128  0.9295843
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was k = 5.
#
# temp   1   2   3   4   5   6
#    1 418  51  54   0   0   0
#    2  24 399  41   5   3   0
#    3  54  21 325   0   0   0
#    4   0   0   0 355  66   0
#    5   0   0   0 131 463   0
#    6   0   0   0   0   0 537
# [1] 0.1526977

# %%
#Applying lda method to data set obtained after dimension reduction using PCA and using Cross-Validation error to determine best model
ctrl <- trainControl(method="cv",number = 10 )  
lda.PCA.10<-train(Y1~.,data=PCA_train_10,trControl=ctrl,method="lda")
print(lda.PCA.10)
temp<-predict(lda.PCA.10,newdata = PCA_test_10)
table(temp,y_test$Y)
error_rate.lda.PCA.10<-mean(temp != y_test$Y)
error_rate.lda.PCA.10
# Out:
# Linear Discriminant Analysis
#
# 7352 samples
#   10 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 6617, 6619, 6616, 6618, 6616, 6616, ...
# Resampling results:
#
#   Accuracy   Kappa
#   0.8339241  0.799958
#
# temp   1   2   3   4   5   6
#    1 456  48  75   0   0   0
#    2  25 422  73   1   0   0
#    3  15   1 272   0   0   0
#    4   0   0   0 268  42  38
#    5   0   0   0 220 490   0
#    6   0   0   0   2   0 499
# [1] 0.1832372

# %%
lda.PCA.40<-train(Y1~.,data=PCA_train_40,trControl=ctrl,method="lda")
print(lda.PCA.40)
temp<-predict(lda.PCA.40,newdata = PCA_test_40)
table(temp,y_test$Y)
error_rate.lda.PCA.40<-mean(temp != y_test$Y)
error_rate.lda.PCA.40

lda.PCA.63<-train(Y1~.,data=PCA_train_63,trControl=ctrl,method="lda")
print(lda.PCA.63)
temp<-predict(lda.PCA.63,newdata = PCA_test_63)
table(temp,y_test$Y)
error_rate.lda.PCA.63<-mean(temp != y_test$Y)
error_rate.lda.PCA.63
# Out:
# Linear Discriminant Analysis
#
# 7352 samples
#   40 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 6620, 6619, 6617, 6615, 6616, 6616, ...
# Resampling results:
#
#   Accuracy   Kappa
#   0.9039603  0.8843256
#
# temp   1   2   3   4   5   6
#    1 480  28  28   0   0   0
#    2   5 440  60   1   0   0
#    3  11   3 332   0   0   0
#    4   0   0   0 375  46  18
#    5   0   0   0 115 486   1
#    6   0   0   0   0   0 518
# [1] 0.1072277
# Linear Discriminant Analysis
#
# 7352 samples
#   63 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold)
# Summary of sample sizes: 6615, 6617, 6617, 6618, 6618, 6616, ...
# Resampling results:
#
#   Accuracy  Kappa
#   0.920423  0.9041694
#
# temp   1   2   3   4   5   6
#    1 478  41  63   0   0   0
#    2   8 422  48   1   0   0
#    3  10   8 309   0   0   0
# ...

# %%
#Lodaing training and testing data set obtained after best subset selection of variables using Random Forest and then running LDA

lda.subset<-train(Y1~.,data=subset_train,trControl=ctrl,method="lda")
print(lda.subset)
temp<-predict(lda.subset,newdata = subset_test)
table(temp,y_test$Y)
error_rate.lda.subset<-mean(temp != y_test$Y)
error_rate.lda.subset
# Out:
# Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”Warning message in lda.default(x, grouping, ...):
# “variables are collinear”
# Linear Discriminant Analysis
#
# 7352 samples
#   36 predictor
#    6 classes: '1', '2', '3', '4', '5', '6'
#
# No pre-processing
# ...

# %%
ctrl <- trainControl(method="cv",number = 10 )  
logistic.PCA.10<-train(Y1~.,data=PCA_train_10,trControl=ctrl,method="multinom")
print(logistic.PCA.10)
temp<-predict(logistic.PCA.10,newdata = PCA_test_10)
table(temp,y_test$Y)
error_rate.logistic.PCA.10<-mean(temp != y_test$Y)
error_rate.logistic.PCA.10


logistic.PCA.40<-train(Y1~.,data=PCA_train_40,trControl=ctrl,method="multinom")
print(logistic.PCA.40)
temp<-predict(logistic.PCA.40,newdata = PCA_test_40)
table(temp,y_test$Y)
error_rate.logistic.PCA.40<-mean(temp != y_test$Y)
error_rate.logistic.PCA.40


logistic.PCA.63<-train(Y1~.,data=PCA_train_63,trControl=ctrl,method="multinom")
print(logistic.PCA.63)
temp<-predict(logistic.PCA.63,newdata = PCA_test_63)
table(temp,y_test$Y)
error_rate.logistic.PCA.63<-mean(temp != y_test$Y)
error_rate.logistic.PCA.63
# Out:
# # weights:  72 (55 variable)
# initial  value 11856.072408
# iter  10 value 3622.964251
# iter  20 value 3242.128976
# iter  30 value 3162.113416
# iter  40 value 2866.234170
# iter  50 value 2661.057514
# iter  60 value 2174.714807
# iter  70 value 2027.091704
# iter  80 value 1929.788661
# iter  90 value 1917.585710
# iter 100 value 1914.744899
# final  value 1914.744899
# stopped after 100 iterations
# # weights:  72 (55 variable)
# initial  value 11856.072408
# iter  10 value 3623.531397
# iter  20 value 3243.335249
# iter  30 value 3163.305955
# iter  40 value 2866.255332
# iter  50 value 2706.394771
# iter  60 value 2167.345900
# iter  70 value 2021.309237
# iter  80 value 1951.769894
# iter  90 value 1941.269625
# iter 100 value 1937.962058
# final  value 1937.962058
# stopped after 100 iterations
# # weights:  72 (55 variable)
# initial  value 11856.072408
# iter  10 value 3622.964818
# iter  20 value 3242.130183
# iter  30 value 3162.114592
# iter  40 value 2866.234233
# ...

# %%
#Applying logistic classification method to data set obtained after subset selection and using Cross-Validation error to determine best model
logistic.subset<-train(Y1~.,data=subset_train,trControl=ctrl,method="multinom")
print(logistic.subset)
temp<-predict(logistic.subset,newdata = subset_test)
table(temp,y_test$Y)
error_rate.logistic.subset<-mean(temp != y_test$Y)
error_rate.logistic.subset
# Out:
# # weights:  228 (185 variable)
# initial  value 11856.072408
# iter  10 value 3523.791776
# iter  20 value 2468.415911
# iter  30 value 1476.637265
# iter  40 value 1118.291230
# iter  50 value 992.526758
# iter  60 value 902.100403
# iter  70 value 861.237462
# iter  80 value 837.411123
# iter  90 value 827.398348
# iter 100 value 821.142194
# final  value 821.142194
# stopped after 100 iterations
# # weights:  228 (185 variable)
# initial  value 11856.072408
# iter  10 value 3531.269261
# iter  20 value 2562.259548
# iter  30 value 1709.588054
# iter  40 value 1460.400074
# iter  50 value 1314.423378
# iter  60 value 1264.325500
# iter  70 value 1249.371631
# iter  80 value 1241.927654
# iter  90 value 1235.007964
# iter 100 value 1233.873884
# final  value 1233.873884
# stopped after 100 iterations
# # weights:  228 (185 variable)
# initial  value 11856.072408
# iter  10 value 3523.799269
# iter  20 value 2468.459900
# iter  30 value 1476.896078
# iter  40 value 1119.072116
# ...

# %%
ctrl <- trainControl(method="cv",number = 10 )  
qda.PCA.10<-train(Y1~.,data=PCA_train_10,trControl=ctrl,method="qda")
print(qda.PCA.10)
temp<-predict(qda.PCA.10,newdata = PCA_test_10)
table(temp,y_test$Y)
error_rate.qda.PCA.10<-mean(temp != y_test$Y)
error_rate.qda.PCA.10


qda.PCA.40<-train(Y1~.,data=PCA_train_40,trControl=ctrl,method="qda")
print(qda.PCA.40)
temp<-predict(qda.PCA.40,newdata = PCA_test_40)
table(temp,y_test$Y)
error_rate.qda.PCA.40<-mean(temp != y_test$Y)
error_rate.qda.PCA.40



qda.PCA.63<-train(Y1~.,data=PCA_train_63,trControl=ctrl,method="qda")
print(qda.PCA.63)
temp<-predict(qda.PCA.63,newdata = PCA_test_63)
table(temp,y_test$Y)
error_rate.qda.PCA.63<-mean(temp != y_test$Y)
error_rate.qda.PCA.63
